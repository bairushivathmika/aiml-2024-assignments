# %%
l1=[1,2,3,4,5]
l2=[6,7,8,9,3]
result=l1+l2
print(result)
print(type(l1+l2))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 3]
# <class 'list'>

# %%
import numpy as np
a=np.array(l1)
b=np.array(l2)
add=a+b
print(add)
print
# Out:
# [ 7  9 11 13  8]
# [ 7  9 11 13  8]

# %%
l1=[[1,1,3,0,8],
[2,5,8,4,6],
[9,4,2,6,8]]
l2=[[2,4,5,6,7],
[6,4,5,3,2],
[9,6,4,3,1]]
r=l1+l2
print(r)
# Out:
# [[1, 1, 3, 0, 8], [2, 5, 8, 4, 6], [9, 4, 2, 6, 8], [2, 4, 5, 6, 7], [6, 4, 5, 3, 2], [9, 6, 4, 3, 1]]

# %%
import numpy as np
a=np.array(l1)
b=np.array(l2)
add=a+b
print(add)
# Out:
# [[ 3  5  8  6 15]
#  [ 8  9 13  7  8]
#  [18 10  6  9  9]]

# %%
import numpy as np
a=np.array(l1)
b=np.array(l2)
mul=a*b
print(mul)
# Out:
# [[ 2  4 15  0 56]
#  [12 20 40 12 12]
#  [81 24  8 18  8]]

# %%
import numpy as np
a=np.array(l1)
transpose=a.T
print(transpose)
# Out:
# [[1 2 9]
#  [1 5 4]
#  [3 8 2]
#  [0 4 6]
#  [8 6 8]]

# %%
import numpy as np
a=np.array(l1)
b=np.array(l2)
# Out:
# [[1 2 9]
#  [1 5 4]
#  [3 8 2]
#  [0 4 6]
#  [8 6 8]]
# [[2 6 9]
#  [4 4 6]
#  [5 5 4]
#  [6 3 3]
#  [7 2 1]]

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[2,3,4,5]
plt.bar(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("graph with x and y")
# Out:
# Text(0.5, 1.0, 'graph with x and y')

# %%
import pandas as pd
pd.read_csv("/content/sample_data/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
import matplotlib.pyplot as plt
x=[-122.05,-118.30,-117.81,-118.36,-119.67,-119.86,-118.14,-119.70,-117.12,-119.63]
y=[37.37,34.26,33.78,33.82,36.33,34.42,34.06,36.30,34.10,34.42]


plt.bar(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("graph with x and y")
# Out:
# Text(0.5, 1.0, 'graph with x and y')

# %%
import pandas as np

d=pd.read_csv("/content/sample_data/california_housing_test.csv")
print(d)
x=d['longitude']
y=d['median_house_value']
plt.bar(x,y)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...
